# %% [markdown]
# <a href="https://colab.research.google.com/github/sreehari7212/Machine-learning/blob/main/titanic_corralasion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("/content/drive/MyDrive/train.csv")

# %%
#plotting by histogram
plt.hist(df["Age"])
plt.show()

# %%
plt.hist(df["Age"],bins=[0,20,40,60,80])
plt.show()

# %%
#female passengers travelled based on class
dff=df[df["Sex"]=="female"].Pclass.value_counts()

# %%
dff
# Out:
# 3    144
# 1     94
# 2     76
# Name: Pclass, dtype: int64

# %%
dff.plot(kind='bar')

# %%
dff.plot(kind='bar',title='Female passengers-classwise',color=['r','g','k'] )

# %%
dfm=df[df["Sex"]=="male"].Pclass.value_counts()
dfm
# Out:
# 3    347
# 1    122
# 2    108
# Name: Pclass, dtype: int64

# %%
fig,axs=plt.subplots(2,1)
dff.plot(kind='bar',title='Female passengers-classwise',color=['r','g','k'],ax=axs[0])
dfm.plot(kind='bar',title='Male passengers-classwise',color=['y','b','c'],ax=axs[1])

# %%
a=df.groupby(['Sex','Pclass']).groups

# %%
a.keys()
# Out:
# dict_keys([('female', 1), ('female', 2), ('female', 3), ('male', 1), ('male', 2), ('male', 3)])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
b=df.groupby(['Sex','Embarked']).group

# %%
b.keys()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-987cf108996b> in <module>
# ----> 1 b.keys()
#
# TypeError: 'list' object is not callable

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(['Name','PassengerId','Ticket'],axis=1)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0       3    male  22.0      1      0   7.2500   NaN        S
# 1           1       1  female  38.0      1      0  71.2833   C85        C
# 2           1       3  female  26.0      0      0   7.9250   NaN        S
# 3           1       1  female  35.0      1      0  53.1000  C123        S
# 4           0       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0       2    male  27.0      0      0  13.0000   NaN        S
# 887         1       1  female  19.0      0      0  30.0000   B42        S
# 888         0       3  female   NaN      1      2  23.4500   NaN        S
# 889         1       1    male  26.0      0      0  30.0000  C148        C
# 890         0       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label=LabelEncoder()

# %%
sex=label.fit_transform(df['Sex'])
cabin=label.fit_transform(df['Cabin'])
embarked=label.fit_transform(df['Embarked'])

# %%
df['Sex']=sex
df['Cabin']=cabin
df['Embarked']=embarked

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.interpolate(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.drop(['Name','PassengerId','Ticket'],axis=1)
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Cabin  Embarked
# 0           0       3    1  22.0      1      0   7.2500    147         2
# 1           1       1    0  38.0      1      0  71.2833     81         0
# 2           1       3    0  26.0      0      0   7.9250    147         2
# 3           1       1    0  35.0      1      0  53.1000     55         2
# 4           0       3    1  35.0      0      0   8.0500    147         2
# ..        ...     ...  ...   ...    ...    ...      ...    ...       ...
# 886         0       2    1  27.0      0      0  13.0000    147         2
# 887         1       1    0  19.0      0      0  30.0000     30         2
# 888         0       3    0  22.5      1      2  23.4500    147         2
# 889         1       1    1  26.0      0      0  30.0000     60         0
# 890         0       3    1  32.0      0      0   7.7500    147         1
#
# [891 rows x 9 columns]

# %%
feature=df.drop(["Survived"],axis=1)
target=df['Survived']

# %%
a=feature.corr()

# %%
a
# Out:
#              PassengerId    Pclass       Sex       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.035144  0.042939  0.025332 -0.057527 -0.001652
# Pclass         -0.035144  1.000000  0.131900 -0.304934  0.083081  0.018443
# Sex             0.042939  0.131900  1.000000  0.061332 -0.114631 -0.245489
# Age             0.025332 -0.304934  0.061332  1.000000 -0.213410 -0.170013
# SibSp          -0.057527  0.083081 -0.114631 -0.213410  1.000000  0.414838
# Parch          -0.001652  0.018443 -0.245489 -0.170013  0.414838  1.000000
# Fare            0.012658 -0.549500 -0.182333  0.087119  0.159651  0.216225
# Cabin          -0.035077  0.684121  0.096681 -0.222197  0.043593 -0.028324
# Embarked        0.013083  0.157112  0.104057 -0.018191  0.066654  0.038322
#
#                  Fare     Cabin  Embarked
# PassengerId  0.012658 -0.035077  0.013083
# Pclass      -0.549500  0.684121  0.157112
# Sex         -0.182333  0.096681  0.104057
# Age          0.087119 -0.222197 -0.018191
# ...

# %%
sns.heatmap(a,annot=True,cmap=plt.cm.CMRmap_r)
